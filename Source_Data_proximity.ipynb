# %% [markdown]
# ### Import modules

# %%
import json
import pandas as pd
import requests
import numpy as np
import re as re

# %% [markdown]
# Please specify industry to upgrade and code (ht6) that best represents the industry:

# %%
industry = 'baterias'
main_ht6_code = 850730

# %% [markdown]
# ### Helpful functions

# %%
def get_countries(code):
    '''
    Gets all the countries that export the product refered by a single code, 
    helpful to do the exact number of queries needed.
    
    Input: A code (string)
    
    Output: list of countries (integers)
    '''
    url = "http://comtrade.un.org/api/get?max=500&type=C&freq=A&px=HS&ps=now&r=all&p=0&rg=2&cc=" + str(code)
    f = requests.get(url, timeout=300)
    x = json.loads(f.text)
    df_prueba = pd.DataFrame(x['dataset'])
    df_prueba = df_prueba[['pfCode', 'period', 'aggrLevel', 'rgDesc', 'rtTitle', 'ptTitle', 'rtCode',
                       'cmdCode', 'cmdDescE', 'TradeQuantity', 'TradeValue']]
    paises = df_prueba['rtCode'].unique().tolist()
    list_paises = [paises[i:i + 5] for i in range(0, len(paises), 5)]
    return list_paises

def query(url):
    '''
    Executes a single query from the UN Comtrade API, converts json object
    into pandas dataframe.
    
    Input: A url (string)
    
    Output: Dataframe with the output of the query (pandas dataframe).
    '''
    f = requests.get(url, timeout=300)
    x = json.loads(f.text)
    df = pd.DataFrame(x['dataset'])
    df = df[['pfCode', 'period', 'aggrLevel', 'rgDesc', 'rtTitle', 'ptTitle',
                       'cmdCode', 'cmdDescE', 'TradeQuantity', 'TradeValue']]
    return df

def query_v2(url):
    '''
    Executes a single query from the UN Comtrade API, converts json object
    into pandas dataframe, modification to include NUMERICAL codes por countries.
    
    Input: A url (string)
    
    Output: Dataframe with the output of the query (pandas dataframe).
    '''
    f = requests.get(url, timeout=300)
    x = json.loads(f.text)
    df = pd.DataFrame(x['dataset'])
    df = df[['pfCode', 'period', 'aggrLevel', 'rgDesc', 'rtTitle', 'ptTitle',
                       'cmdCode', 'cmdDescE', 'TradeQuantity', 'TradeValue', 'rtCode']]
    return df

# %% [markdown]
# Initialize dataframe called 'base'. Initialize lists (helpful to start at the place the last run ended, do not repeat, just run once) and load codes from csv in the directory.

# %%
data = []
base = pd.DataFrame(data, columns=['pfCode', 'period', 'aggrLevel', 'rgDesc', 'rtTitle', 'ptTitle',
                       'cmdCode', 'cmdDescE', 'TradeQuantity', 'TradeValue'])

string = 'codes_' + industry + '.csv'
codes_all = pd.read_csv(string)
codes_all = codes_all.astype(str)
codes_all = codes_all['code'].to_list()
lst_check, lst_code = [], [0,0]

# %% [markdown]
# ### Download data

# %% [markdown]
# Repeat the next chunk until all the codes are covered, you can check this down by checking the base dataframe.

# %%
for cod in codes_all:
    if cod not in lst_code:
        print(cod)
        for sublist in get_countries(cod):
            string = '' + str(sublist[0])
            for con in sublist[1:]:
                string = string + '%2C' + str(con)
            comb = str(cod) + str(string)
            if comb not in lst_check:
                url = "http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=" + str(string) + "&p=all&rg=2&cc=" + str(cod)
                print(url)
                row = query(url)
                base = pd.concat([base, row])
                lst_check.append(comb)
                print(url, cod, comb)
        lst_code.append(cod)
# Out:
# 253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=31%2C32%2C36%2C40%2C51&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=31%2C32%2C36%2C40%2C51&p=all&rg=2&cc=253090 253090 25309031%2C32%2C36%2C40%2C51
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=56%2C68%2C70%2C72%2C76&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=56%2C68%2C70%2C72%2C76&p=all&rg=2&cc=253090 253090 25309056%2C68%2C70%2C72%2C76
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=104%2C112%2C156%2C170%2C191&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=104%2C112%2C156%2C170%2C191&p=all&rg=2&cc=253090 253090 253090104%2C112%2C156%2C170%2C191
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=196%2C203%2C208%2C222%2C233&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=196%2C203%2C208%2C222%2C233&p=all&rg=2&cc=253090 253090 253090196%2C203%2C208%2C222%2C233
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=246%2C251%2C276%2C300%2C320&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=246%2C251%2C276%2C300%2C320&p=all&rg=2&cc=253090 253090 253090246%2C251%2C276%2C300%2C320
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=328%2C344%2C348%2C360%2C372&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=328%2C344%2C348%2C360%2C372&p=all&rg=2&cc=253090 253090 253090328%2C344%2C348%2C360%2C372
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=376%2C381%2C392%2C400%2C404&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=376%2C381%2C392%2C400%2C404&p=all&rg=2&cc=253090 253090 253090376%2C381%2C392%2C400%2C404
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=410%2C417%2C422%2C428%2C440&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=410%2C417%2C422%2C428%2C440&p=all&rg=2&cc=253090 253090 253090410%2C417%2C422%2C428%2C440
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=442%2C458%2C490%2C498%2C499&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=442%2C458%2C490%2C498%2C499&p=all&rg=2&cc=253090 253090 253090442%2C458%2C490%2C498%2C499
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=516%2C528%2C554%2C579%2C586&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=516%2C528%2C554%2C579%2C586&p=all&rg=2&cc=253090 253090 253090516%2C528%2C554%2C579%2C586
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=608%2C616%2C642%2C686%2C688&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=608%2C616%2C642%2C686%2C688&p=all&rg=2&cc=253090 253090 253090608%2C616%2C642%2C686%2C688
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=699%2C702%2C703%2C704%2C705&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=699%2C702%2C703%2C704%2C705&p=all&rg=2&cc=253090 253090 253090699%2C702%2C703%2C704%2C705
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=710%2C716%2C724%2C752%2C757&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=710%2C716%2C724%2C752%2C757&p=all&rg=2&cc=253090 253090 253090710%2C716%2C724%2C752%2C757
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=764%2C792%2C800%2C804%2C807&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=764%2C792%2C800%2C804%2C807&p=all&rg=2&cc=253090 253090 253090764%2C792%2C800%2C804%2C807
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=826%2C842%2C858%2C860%2C894&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=826%2C842%2C858%2C860%2C894&p=all&rg=2&cc=253090 253090 253090826%2C842%2C858%2C860%2C894
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=180%2C484%2C533%2C818&p=all&rg=2&cc=253090
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=180%2C484%2C533%2C818&p=all&rg=2&cc=253090 253090 253090180%2C484%2C533%2C818
# 283691
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=32%2C36%2C40%2C56%2C76&p=all&rg=2&cc=283691
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=32%2C36%2C40%2C56%2C76&p=all&rg=2&cc=283691 283691 28369132%2C36%2C40%2C56%2C76
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=156%2C191%2C203%2C208%2C246&p=all&rg=2&cc=283691
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=156%2C191%2C203%2C208%2C246&p=all&rg=2&cc=283691 283691 283691156%2C191%2C203%2C208%2C246
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=251%2C276%2C300%2C320%2C348&p=all&rg=2&cc=283691
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=251%2C276%2C300%2C320%2C348&p=all&rg=2&cc=283691 283691 283691251%2C276%2C300%2C320%2C348
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=372%2C381%2C392%2C404%2C410&p=all&rg=2&cc=283691
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=372%2C381%2C392%2C404%2C410&p=all&rg=2&cc=283691 283691 283691372%2C381%2C392%2C404%2C410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=428%2C440%2C458%2C490%2C528&p=all&rg=2&cc=283691
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=428%2C440%2C458%2C490%2C528&p=all&rg=2&cc=283691 283691 283691428%2C440%2C458%2C490%2C528
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=554%2C616%2C699%2C702%2C705&p=all&rg=2&cc=283691
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=554%2C616%2C699%2C702%2C705&p=all&rg=2&cc=283691 283691 283691554%2C616%2C699%2C702%2C705
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=710%2C716%2C724%2C752%2C757&p=all&rg=2&cc=283691
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=710%2C716%2C724%2C752%2C757&p=all&rg=2&cc=283691 283691 283691710%2C716%2C724%2C752%2C757
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=764%2C792%2C826%2C842&p=all&rg=2&cc=283691
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=764%2C792%2C826%2C842&p=all&rg=2&cc=283691 283691 283691764%2C792%2C826%2C842
# 250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C40%2C56%2C76%2C112&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C40%2C56%2C76%2C112&p=all&rg=2&cc=250410 250410 25041036%2C40%2C56%2C76%2C112
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=144%2C156%2C170%2C203%2C208&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=144%2C156%2C170%2C203%2C208&p=all&rg=2&cc=250410 250410 250410144%2C156%2C170%2C203%2C208
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=222%2C233%2C246%2C251%2C276&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=222%2C233%2C246%2C251%2C276&p=all&rg=2&cc=250410 250410 250410222%2C233%2C246%2C251%2C276
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=300%2C344%2C348%2C360%2C381&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=300%2C344%2C348%2C360%2C381&p=all&rg=2&cc=250410 250410 250410300%2C344%2C348%2C360%2C381
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=392%2C410%2C440%2C442%2C458&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=392%2C410%2C440%2C442%2C458&p=all&rg=2&cc=250410 250410 250410392%2C410%2C440%2C442%2C458
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=490%2C516%2C528%2C586%2C616&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=490%2C516%2C528%2C586%2C616&p=all&rg=2&cc=250410 250410 250410490%2C516%2C528%2C586%2C616
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=642%2C688%2C699%2C702%2C704&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=642%2C688%2C699%2C702%2C704&p=all&rg=2&cc=250410 250410 250410642%2C688%2C699%2C702%2C704
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=705%2C710%2C716%2C724%2C752&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=705%2C710%2C716%2C724%2C752&p=all&rg=2&cc=250410 250410 250410705%2C710%2C716%2C724%2C752
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=757%2C764%2C792%2C804%2C826&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=757%2C764%2C792%2C804%2C826&p=all&rg=2&cc=250410 250410 250410757%2C764%2C792%2C804%2C826
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=842%2C484%2C818&p=all&rg=2&cc=250410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=842%2C484%2C818&p=all&rg=2&cc=250410 250410 250410842%2C484%2C818
# 271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=31%2C36%2C40%2C56%2C76&p=all&rg=2&cc=271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=31%2C36%2C40%2C56%2C76&p=all&rg=2&cc=271312 271312 27131231%2C36%2C40%2C56%2C76
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=156%2C170%2C203%2C246%2C251&p=all&rg=2&cc=271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=156%2C170%2C203%2C246%2C251&p=all&rg=2&cc=271312 271312 271312156%2C170%2C203%2C246%2C251
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=276%2C300%2C348%2C352%2C360&p=all&rg=2&cc=271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=276%2C300%2C348%2C352%2C360&p=all&rg=2&cc=271312 271312 271312276%2C300%2C348%2C352%2C360
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=381%2C392%2C404%2C410%2C440&p=all&rg=2&cc=271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=381%2C392%2C404%2C410%2C440&p=all&rg=2&cc=271312 271312 271312381%2C392%2C404%2C410%2C440
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=458%2C528%2C554%2C579%2C586&p=all&rg=2&cc=271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=458%2C528%2C554%2C579%2C586&p=all&rg=2&cc=271312 271312 271312458%2C528%2C554%2C579%2C586
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=616%2C642%2C688%2C699%2C702&p=all&rg=2&cc=271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=616%2C642%2C688%2C699%2C702&p=all&rg=2&cc=271312 271312 271312616%2C642%2C688%2C699%2C702
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=703%2C705%2C710%2C724%2C752&p=all&rg=2&cc=271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=703%2C705%2C710%2C724%2C752&p=all&rg=2&cc=271312 271312 271312703%2C705%2C710%2C724%2C752
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=757%2C764%2C792%2C804%2C842&p=all&rg=2&cc=271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=757%2C764%2C792%2C804%2C842&p=all&rg=2&cc=271312 271312 271312757%2C764%2C792%2C804%2C842
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=818&p=all&rg=2&cc=271312
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=818&p=all&rg=2&cc=271312 271312 271312818
# 260500
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C156%2C246%2C251%2C276&p=all&rg=2&cc=260500
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C156%2C246%2C251%2C276&p=all&rg=2&cc=260500 260500 26050036%2C156%2C246%2C251%2C276
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=344%2C372%2C392%2C404%2C490&p=all&rg=2&cc=260500
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=344%2C372%2C392%2C404%2C490&p=all&rg=2&cc=260500 260500 260500344%2C372%2C392%2C404%2C490
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=516%2C699%2C703%2C710%2C724&p=all&rg=2&cc=260500
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=516%2C699%2C703%2C710%2C724&p=all&rg=2&cc=260500 260500 260500516%2C699%2C703%2C710%2C724
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=764%2C792%2C826%2C842%2C894&p=all&rg=2&cc=260500
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=764%2C792%2C826%2C842%2C894&p=all&rg=2&cc=260500 260500 260500764%2C792%2C826%2C842%2C894
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=180&p=all&rg=2&cc=260500
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=180&p=all&rg=2&cc=260500 260500 260500180
# 260400
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=8%2C36%2C40%2C56%2C76&p=all&rg=2&cc=260400
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=8%2C36%2C40%2C56%2C76&p=all&rg=2&cc=260400 260400 2604008%2C36%2C40%2C56%2C76
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=156%2C246%2C251%2C276%2C300&p=all&rg=2&cc=260400
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=156%2C246%2C251%2C276%2C300&p=all&rg=2&cc=260400 260400 260400156%2C246%2C251%2C276%2C300
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=320%2C348%2C360%2C372%2C381&p=all&rg=2&cc=260400
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=320%2C348%2C360%2C372%2C381&p=all&rg=2&cc=260400 260400 260400320%2C348%2C360%2C372%2C381
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=410%2C458%2C490%2C528%2C579&p=all&rg=2&cc=260400
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=410%2C458%2C490%2C528%2C579&p=all&rg=2&cc=260400 260400 260400410%2C458%2C490%2C528%2C579
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=608%2C702%2C705%2C710%2C716&p=all&rg=2&cc=260400
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=608%2C702%2C705%2C710%2C716&p=all&rg=2&cc=260400 260400 260400608%2C702%2C705%2C710%2C716
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=724%2C752%2C757%2C764%2C792&p=all&rg=2&cc=260400
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=724%2C752%2C757%2C764%2C792&p=all&rg=2&cc=260400 260400 260400724%2C752%2C757%2C764%2C792
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=826%2C842%2C894&p=all&rg=2&cc=260400
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=826%2C842%2C894&p=all&rg=2&cc=260400 260400 260400826%2C842%2C894
# 280519
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C40%2C56%2C76%2C156&p=all&rg=2&cc=280519
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C40%2C56%2C76%2C156&p=all&rg=2&cc=280519 280519 28051936%2C40%2C56%2C76%2C156
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=203%2C208%2C233%2C246%2C251&p=all&rg=2&cc=280519
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=203%2C208%2C233%2C246%2C251&p=all&rg=2&cc=280519 280519 280519203%2C208%2C233%2C246%2C251
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=276%2C300%2C344%2C360%2C372&p=all&rg=2&cc=280519
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=276%2C300%2C344%2C360%2C372&p=all&rg=2&cc=280519 280519 280519276%2C300%2C344%2C360%2C372
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=376%2C381%2C392%2C404%2C410&p=all&rg=2&cc=280519
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=376%2C381%2C392%2C404%2C410&p=all&rg=2&cc=280519 280519 280519376%2C381%2C392%2C404%2C410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=440%2C458%2C490%2C528%2C554&p=all&rg=2&cc=280519
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=440%2C458%2C490%2C528%2C554&p=all&rg=2&cc=280519 280519 280519440%2C458%2C490%2C528%2C554
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=579%2C608%2C616%2C699%2C702&p=all&rg=2&cc=280519
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=579%2C608%2C616%2C699%2C702&p=all&rg=2&cc=280519 280519 280519579%2C608%2C616%2C699%2C702
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=705%2C710%2C724%2C752%2C757&p=all&rg=2&cc=280519
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=705%2C710%2C724%2C752%2C757&p=all&rg=2&cc=280519 280519 280519705%2C710%2C724%2C752%2C757
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=764%2C792%2C826%2C842%2C818&p=all&rg=2&cc=280519
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=764%2C792%2C826%2C842%2C818&p=all&rg=2&cc=280519 280519 280519764%2C792%2C826%2C842%2C818
# 282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=32%2C36%2C40%2C51%2C56&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=32%2C36%2C40%2C51%2C56&p=all&rg=2&cc=282739 282739 28273932%2C36%2C40%2C51%2C56
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=68%2C70%2C72%2C76%2C112&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=68%2C70%2C72%2C76%2C112&p=all&rg=2&cc=282739 282739 28273968%2C70%2C72%2C76%2C112
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=144%2C156%2C170%2C191%2C196&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=144%2C156%2C170%2C191%2C196&p=all&rg=2&cc=282739 282739 282739144%2C156%2C170%2C191%2C196
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=203%2C208%2C222%2C233%2C246&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=203%2C208%2C222%2C233%2C246&p=all&rg=2&cc=282739 282739 282739203%2C208%2C222%2C233%2C246
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=251%2C276%2C300%2C320%2C328&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=251%2C276%2C300%2C320%2C328&p=all&rg=2&cc=282739 282739 282739251%2C276%2C300%2C320%2C328
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=344%2C348%2C360%2C372%2C376&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=344%2C348%2C360%2C372%2C376&p=all&rg=2&cc=282739 282739 282739344%2C348%2C360%2C372%2C376
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=381%2C392%2C400%2C404%2C410&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=381%2C392%2C400%2C404%2C410&p=all&rg=2&cc=282739 282739 282739381%2C392%2C400%2C404%2C410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=428%2C440%2C442%2C458%2C480&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=428%2C440%2C442%2C458%2C480&p=all&rg=2&cc=282739 282739 282739428%2C440%2C442%2C458%2C480
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=490%2C499%2C516%2C528%2C554&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=490%2C499%2C516%2C528%2C554&p=all&rg=2&cc=282739 282739 282739490%2C499%2C516%2C528%2C554
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=579%2C586%2C616%2C642%2C688&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=579%2C586%2C616%2C642%2C688&p=all&rg=2&cc=282739 282739 282739579%2C586%2C616%2C642%2C688
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=699%2C702%2C703%2C704%2C705&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=699%2C702%2C703%2C704%2C705&p=all&rg=2&cc=282739 282739 282739699%2C702%2C703%2C704%2C705
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=710%2C724%2C752%2C757%2C764&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=710%2C724%2C752%2C757%2C764&p=all&rg=2&cc=282739 282739 282739710%2C724%2C752%2C757%2C764
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=792%2C800%2C804%2C807%2C826&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=792%2C800%2C804%2C807%2C826&p=all&rg=2&cc=282739 282739 282739792%2C800%2C804%2C807%2C826
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=842%2C858%2C484%2C818&p=all&rg=2&cc=282739
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=842%2C858%2C484%2C818&p=all&rg=2&cc=282739 282739 282739842%2C858%2C484%2C818
# 282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C40%2C56%2C76%2C112&p=all&rg=2&cc=282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C40%2C56%2C76%2C112&p=all&rg=2&cc=282690 282690 28269036%2C40%2C56%2C76%2C112
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=156%2C170%2C191%2C203%2C233&p=all&rg=2&cc=282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=156%2C170%2C191%2C203%2C233&p=all&rg=2&cc=282690 282690 282690156%2C170%2C191%2C203%2C233
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=246%2C251%2C276%2C300%2C320&p=all&rg=2&cc=282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=246%2C251%2C276%2C300%2C320&p=all&rg=2&cc=282690 282690 282690246%2C251%2C276%2C300%2C320
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=344%2C381%2C392%2C404%2C410&p=all&rg=2&cc=282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=344%2C381%2C392%2C404%2C410&p=all&rg=2&cc=282690 282690 282690344%2C381%2C392%2C404%2C410
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=428%2C440%2C442%2C458%2C490&p=all&rg=2&cc=282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=428%2C440%2C442%2C458%2C490&p=all&rg=2&cc=282690 282690 282690428%2C440%2C442%2C458%2C490
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=516%2C528%2C554%2C579%2C616&p=all&rg=2&cc=282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=516%2C528%2C554%2C579%2C616&p=all&rg=2&cc=282690 282690 282690516%2C528%2C554%2C579%2C616
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=688%2C699%2C702%2C704%2C705&p=all&rg=2&cc=282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=688%2C699%2C702%2C704%2C705&p=all&rg=2&cc=282690 282690 282690688%2C699%2C702%2C704%2C705
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=710%2C724%2C752%2C757%2C764&p=all&rg=2&cc=282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=710%2C724%2C752%2C757%2C764&p=all&rg=2&cc=282690 282690 282690710%2C724%2C752%2C757%2C764
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=792%2C826%2C842%2C484%2C818&p=all&rg=2&cc=282690
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=792%2C826%2C842%2C484%2C818&p=all&rg=2&cc=282690 282690 282690792%2C826%2C842%2C484%2C818
# 282520
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C40%2C56%2C76%2C156&p=all&rg=2&cc=282520
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=36%2C40%2C56%2C76%2C156&p=all&rg=2&cc=282520 282520 28252036%2C40%2C56%2C76%2C156
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=203%2C233%2C251%2C300%2C344&p=all&rg=2&cc=282520
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=203%2C233%2C251%2C300%2C344&p=all&rg=2&cc=282520 282520 282520203%2C233%2C251%2C300%2C344
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=372%2C381%2C392%2C410%2C428&p=all&rg=2&cc=282520
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=372%2C381%2C392%2C410%2C428&p=all&rg=2&cc=282520 282520 282520372%2C381%2C392%2C410%2C428
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=440%2C458%2C528%2C554%2C616&p=all&rg=2&cc=282520
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=440%2C458%2C528%2C554%2C616&p=all&rg=2&cc=282520 282520 282520440%2C458%2C528%2C554%2C616
# http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=642%2C699%2C702%2C710%2C724&p=all&rg=2&cc=282520
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-19-255f0265cce4> in <module>
#      10                 url = "http://comtrade.un.org/api/get?max=50000&type=C&freq=A&px=HS&ps=2020&r=" + str(string) + "&p=all&rg=2&cc=" + str(cod)
#      11                 print(url)
# ---> 12                 row = query(url)
#      13                 base = pd.concat([base, row])
#      14                 lst_check.append(comb)
#
# <ipython-input-17-97ae5b9812bb> in query(url)
#      28     '''
#      29     f = requests.get(url, timeout=300)
# ---> 30     x = json.loads(f.text)
#      31     df = pd.DataFrame(x['dataset'])
#      32     df = df[['pfCode', 'period', 'aggrLevel', 'rgDesc', 'rtTitle', 'ptTitle',
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# Save to a csv just to have a back-up between runs of the code.

# %%
string = 'base_' + industry + '.csv'
base.to_csv (string, index = False, header=True)
base

# %% [markdown]
# ### Add stage of the value chain and save in a csv.

# %%
#Pedro's file
base = pd.read_csv(string)
stages = pd.read_excel (r'Descripciones.xlsx', sheet_name = industry)
stages.rename(columns = {'HT6 Code':'cmdCode'}, inplace = True)
stages["cmdCode"] = stages["cmdCode"].astype('str')
base["cmdCode"] = base["cmdCode"].astype('str')

#Vlook up of phases provided and main base with HT6 Codes
final_df  = pd.merge(base, stages, on ='cmdCode', how ='left')
final_df = final_df[["pfCode", "period", "aggrLevel", "rgDesc", "rtTitle", "ptTitle", "cmdCode",
                     "cmdDescE", "Naic_descrip", "TradeQuantity", "TradeValue", "PHASE", "COMPLEXITY"]]
final_df.rename(columns = {'rtTitle':'From', 'ptTitle':'To'}, inplace = True)
final_df
# Out:
#       pfCode  period  aggrLevel  rgDesc       From          To cmdCode  \
# 0         H4    2020          6  Export      Aruba  Areas, nes  253090
# 1         H4    2020          6  Export      Aruba  Areas, nes  850760
# 2         H4    2020          6  Export      Aruba  Areas, nes  850780
# 3         H5    2020          6  Export  Australia     Armenia  253090
# 4         H5    2020          6  Export    Austria     Albania  253090
# ...      ...     ...        ...     ...        ...         ...     ...
# 33031     H5    2020          6  Export     Zambia    Zimbabwe  850720
# 33032     H5    2020          6  Export     Zambia    Zimbabwe  850760
# 33033     H5    2020          6  Export   Zimbabwe      Zambia  850780
# 33034     H5    2020          6  Export     Zambia    Zimbabwe  850780
# 33035     H5    2020          6  Export     Zambia    Zimbabwe  854519
#
#                                                 cmdDescE  \
# 0               Mineral substances; n.e.c. in chapter 25
# 1      Electric accumulators; lithium-ion, including ...
# 2      Electric accumulators; other than lead-acid, n...
# 3               Mineral substances; n.e.c. in chapter 25
# 4               Mineral substances; n.e.c. in chapter 25
# ...                                                  ...
# 33031  Electric accumulators; lead-acid, (other than ...
# 33032  Electric accumulators; lithium-ion, including ...
# 33033  Electric accumulators; other than lead-acid, n...
# 33034  Electric accumulators; other than lead-acid, n...
# 33035  Carbon electrodes; with or without metal, of a...
#
#                             Naic_descrip  TradeQuantity  TradeValue  \
# 0              MINERAL SUBSTANCES, NESOI             64         100
# 1                  LITHIUM ION BATTERIES              0         975
# 2                STORAGE BATTERIES NESOI              0         731
# 3              MINERAL SUBSTANCES, NESOI             89        6966
# 4              MINERAL SUBSTANCES, NESOI          18000        6109
# ...                                  ...            ...         ...
# 33031  LEAD-ACID STORAGE BATTERIES NESOI           2533      190610
# 33032              LITHIUM ION BATTERIES              0       14598
# 33033            STORAGE BATTERIES NESOI              0       15792
# 33034            STORAGE BATTERIES NESOI              0       17822
# 33035            CARBON ELECTRODES NESOI            800       16791
#
#             PHASE  COMPLEXITY
# 0       Upstring          NaN
# 1      Downstream         NaN
# 2      Downstream         NaN
# 3       Upstring          NaN
# 4       Upstring          NaN
# ...           ...         ...
# 33031  Downstream         NaN
# 33032  Downstream         NaN
# 33033  Downstream         NaN
# 33034  Downstream         NaN
# 33035   Midstream         NaN
#
# [33036 rows x 13 columns]

# %% [markdown]
# ### Correct that every code has the same description

# %%
grouped_df = final_df.groupby("cmdCode")
first_values = grouped_df.first()
first_values = first_values.reset_index()
first_values = first_values[['cmdCode', 'cmdDescE']]
first_values.rename(columns = {'cmdDescE':'des'}, inplace = True)
corrected_df  = pd.merge(final_df, first_values, on ='cmdCode', how ='left')
del corrected_df['cmdDescE']
corrected_df.rename(columns = {'des':'cmdDescE'}, inplace = True)

# %% [markdown]
# ### Construct indicator that a relation between countries is repeated for one product

# %%
corrected_df["max"] = corrected_df[["From", "To"]].max(axis=1)
corrected_df["min"] =  corrected_df[["From", "To"]].min(axis=1)
corrected_df["cmdCode"] = corrected_df["cmdCode"].astype('str')
corrected_df = corrected_df.sort_values(by=["max", "min", "cmdCode"]).reset_index(drop=True)
duplicate_df = corrected_df[["max", "min", "cmdCode"]]
duplicate_df = duplicate_df.assign(is_duplicate= lambda d: d.duplicated()).sort_values(["max", "min", "cmdCode"]).reset_index(drop=True)
corrected_df["is_duplicate"] = duplicate_df["is_duplicate"].astype(int)
corrected_df["is_duplicated"]= np.where(corrected_df["is_duplicate"]==0, '#00FF00', '#FF0000')

# %% [markdown]
# ### Add Balassa Index

# %%
final_df = corrected_df

def balassa_index(final_df):
    
    data_empty = []
    total_exp = pd.DataFrame(data_empty, columns=['pfCode', 'period', 'aggrLevel', 'rgDesc', 'rtTitle', 'ptTitle',
                       'cmdCode', 'cmdDescE', 'TradeQuantity', 'TradeValue'])
    
    url = "http://comtrade.un.org/api/get?max=502&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=2&cc=TOTAL"
    print(url)
    row = query(url)
    
    #Country's i total export of good k to the World
    exp_good_country = final_df.groupby(["From", "cmdCode"]).sum().reset_index()[["From", "cmdCode", "TradeValue"]]
    exp_good_country.rename(columns = {"TradeValue":'exp_good_country'}, inplace = True)
    final_df = pd.merge(final_df, exp_good_country, on = ["From", "cmdCode"] , how ='left')
    
    #Country's total exports to the world
    total_exp_country = pd.concat([total_exp, row])
    total_exp_country = total_exp_country[["rtTitle", "TradeValue", "period"]]
    total_exp_country.rename(columns = {"TradeValue":'total_exp_country', "rtTitle":'From'}, inplace = True)
    final_df = pd.merge(final_df, total_exp_country[["From","total_exp_country"]], on ='From', how ='left')
    
    #World export of good k
    exp_good = final_df.groupby(["cmdCode"]).sum().reset_index()[["cmdCode", "TradeValue"]]
    exp_good.rename(columns = {"TradeValue":'exp_good'}, inplace = True)
    final_df = pd.merge(final_df, exp_good, on ='cmdCode', how ='left')
    
    #World total exports
    total_exp = total_exp_country.groupby(["period"]).sum().reset_index()[["total_exp_country"]]
    final_df["total_exp"] = int(total_exp['total_exp_country'].values[0])
    
    #Balassa index
    final_df["balassa"] = (final_df["exp_good_country"] / final_df["total_exp_country"]) / (final_df["exp_good"] / final_df["total_exp"])
    return final_df 

final_df = balassa_index(final_df)
final_df = final_df[['pfCode', 'period', 'aggrLevel', 'rgDesc', 'From', 'To', 'cmdCode',
       'Naic_descrip', 'TradeQuantity', 'TradeValue', 'PHASE', 'COMPLEXITY',
       'max', 'min', 'cmdDescE', 'is_duplicated','balassa', 'is_duplicate']]
# Out:
# http://comtrade.un.org/api/get?max=502&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=2&cc=TOTAL

# %% [markdown]
# ### Add broader description of products for semiconductors

# %%
string = industry + '_traduccion.csv'
broad = pd.read_csv(string)[['naics_6', 'naics_description', 'cmdCode']]
broad["cmdCode"] = broad["cmdCode"].astype('str')
final_df["cmdCode"] = final_df["cmdCode"].astype('str')
broad = broad[broad['cmdCode'].isin(final_df['cmdCode'].unique().tolist())]
final_df = pd.merge(final_df, broad, on ='cmdCode', how ='left')
string = 'db_trade_f_' + industry + '.csv '
final_df.to_csv (string, index = False, header=True)

# %% [markdown]
# ### Add proximity index

# %% [markdown]
# Calculate total of countries to take into account for the index and create empty structures to store information.

# %%
url = "http://comtrade.un.org/api/get?max=502&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=2&cc=TOTAL"
print(url)
result_query = query_v2(url)
countries = result_query['rtCode'].unique().tolist()
empty = []
all_products = pd.DataFrame(empty, columns=['pfCode', 'period', 'aggrLevel', 'rgDesc', 'rtTitle', 'ptTitle',
                       'cmdCode', 'cmdDescE', 'TradeQuantity', 'TradeValue'])
lst_countries = []
# Out:
# http://comtrade.un.org/api/get?max=502&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=2&cc=TOTAL

# %% [markdown]
# For loop to get data of all products that every country exports. (repeat until you get all de countries)

# %%
for c in countries:
    if c not in lst_countries:
        url = "http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=" + str(c) + "&p=0&rg=2&cc=ALL"
        print(url)
        row = query(url)
        all_products = pd.concat([all_products, row])
        lst_countries.append(c)
# Out:
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=8&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=31&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=32&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=36&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=40&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=51&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=52&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=56&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=60&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=68&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=70&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=72&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=76&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=84&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=104&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=112&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=124&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=144&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=156&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=170&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=191&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=196&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=203&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=208&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=222&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=233&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=246&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=251&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=268&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=276&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=300&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=320&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=328&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=344&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=348&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=352&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=360&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=372&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=376&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=381&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=392&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=400&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=404&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=410&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=417&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=422&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=428&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=440&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=442&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=446&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=458&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=480&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=490&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=498&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=499&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=516&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=528&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=554&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=579&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=586&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=608&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=616&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=620&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=634&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=642&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=686&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=688&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=699&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=702&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=703&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=704&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=705&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=710&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=716&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=724&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=752&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=757&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=764&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=792&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=800&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=804&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=807&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=826&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=842&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=858&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=860&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=894&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=180&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=270&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=308&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=484&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=533&p=0&rg=2&cc=ALL
# http://comtrade.un.org/api/get?max=100000&type=C&freq=A&px=HS&ps=2020&r=818&p=0&rg=2&cc=ALL

# %% [markdown]
# Know codes for the industry

# %%
HT6_industry = pd.read_excel (r'Descripciones.xlsx', sheet_name= industry)
industry_codes = HT6_industry['HT6 Code'].unique().tolist()
industry_codes = list(map(str, industry_codes))

# %% [markdown]
# Add balassa to all products

# %%
all_products.rename(columns = {"rtTitle":'From'}, inplace = True)
all_products = all_products[all_products['cmdCode'] != 'TOTAL']
all_products[["cmdCode", "period", "aggrLevel", "TradeQuantity", "TradeValue"]] = all_products[["cmdCode", "period", "aggrLevel", "TradeQuantity", "TradeValue"]].apply(pd.to_numeric)
all_products_balassa = balassa_index(all_products)
all_products_balassa = all_products_balassa[['pfCode', 'period', 'aggrLevel', 'rgDesc', 'From', 'ptTitle', 'cmdCode',
       'TradeQuantity', 'TradeValue', 'cmdDescE','balassa']]
all_products_balassa = all_products_balassa[all_products_balassa['balassa'] >= 1]
# Out:
# http://comtrade.un.org/api/get?max=502&type=C&freq=A&px=HS&ps=2020&r=all&p=0&rg=2&cc=TOTAL

# %% [markdown]
# ### Construct proximity index

# %%
#Calculate countries that export both

countries_industry = all_products_balassa[all_products_balassa['cmdCode'] == main_ht6_code][['From']]
countries_industry['yes_no'] = 1
countries_industry = pd.merge(all_products_balassa, countries_industry, on ='From', how ='left')
countries_industry['yes_no'] = countries_industry['yes_no'].fillna(0)
join_products = countries_industry.groupby(['cmdDescE', 'cmdCode', 'yes_no']).count().reset_index()[['pfCode', 'cmdCode', 'yes_no']]
join_products.rename(columns = {"pfCode":'count_join'}, inplace = True)
join_products = join_products[join_products['yes_no'] == 1]


#Calculate countries that export each product

count_products = all_products_balassa.groupby(['cmdDescE', 'cmdCode']).count().reset_index()[['pfCode', 'cmdCode', 'cmdDescE']]
count_products.rename(columns = {"pfCode":'count_countries'}, inplace = True)


#Calculate proximity indicator by using the past 2 measures
final_df_merge = pd.merge(count_products, join_products, on ='cmdCode', how ='left')
final_df_merge['industry_count'] = len(all_products_balassa[all_products_balassa['cmdCode'] == main_ht6_code]['From'].unique().tolist())
final_df_merge = final_df_merge[final_df_merge['yes_no'] == 1]
final_df_merge['max'] = final_df_merge[["industry_count", "count_countries"]].max(axis=1)
final_df_merge['proximity'] = final_df_merge['count_join'] / final_df_merge['max']
final_df_merge["cmdCode"] = final_df_merge["cmdCode"].astype(str)
final_df_merge['num_digits'] = final_df_merge['cmdCode'].str.len()
final_df_merge = final_df_merge[final_df_merge['num_digits'] == 6][['cmdCode', 'cmdDescE','proximity']]
final_df_merge = final_df_merge[~final_df_merge['cmdCode'].isin(industry_codes)][['cmdCode', 'cmdDescE','proximity']]
final_df_merge = final_df_merge.sort_values(by= 'proximity', ascending = False)

# %%
#Filter products in which Mexico is specialized
mexico_specialized = all_products_balassa[all_products_balassa['From'] == 'Mexico']['cmdCode'].unique().tolist()
mexico_specialized = [str(integer) for integer in mexico_specialized]
final_df_merge[final_df_merge['cmdCode'].isin(mexico_specialized)]
string = industry + '_proximity.csv'
final_df_merge.to_csv (string, index = False, header=True)

# %% [markdown]
# ### Design documents for igraph

# %%
def prepare_edges_nodes(proximity_doc_string, number_of_nodes):

    #Nodes
    final_df_merge = pd.read_csv(proximity_doc_string)
    data_empty = pd.DataFrame([[main_ht6_code, str(industry), 1]], columns=['cmdCode', 'cmdDescE', 'proximity'])
    graph = pd.concat([data_empty,final_df_merge])                                                       
    graph = graph.sort_values(by= 'proximity', ascending = False)
    graph.insert(0, 'id', range(1, 1 + len(graph)))
    graph['Label'] = graph['cmdDescE'].apply(lambda x: x.split(';')[0])
    graph['Label'] = graph['Label'].apply(lambda x: x.split(',')[0])
    graph['proximity'] = graph['proximity'] * 10
    graph['proximity'] = graph['proximity'].apply(np.ceil)
    nodes = graph[['id', 'cmdCode', 'Label', 'proximity']].head(number_of_nodes)
    nodes_string = industry + '_nodes.csv'
    nodes.to_csv (nodes_string, index = False, header=True)
    
    #Edges
    edges = final_df_merge 
    edges.insert(0, 'from', 1)
    edges.insert(0, 'to', range(2, 2 + len(edges)))
    edges['weight'] = edges['proximity']*10
    edges['weight'] = edges['weight'].apply(np.ceil)
    edges = edges[['from', 'to', 'weight']].head(number_of_nodes - 1)
    edges_string = industry + '_edges.csv'
    edges.to_csv (edges_string, index = False, header=True)
    
prepare_edges_nodes(string, 28)
